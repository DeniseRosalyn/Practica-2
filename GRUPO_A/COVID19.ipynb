# %%
import pandas as pd
import numpy as np

# %%
# CASOS POR DÍA
ct= pd.read_csv('https://covid.ourworldindata.org/data/ecdc/total_cases.csv').fillna(0) #NÚMERO DE CASOS TOTALES
mt = pd.read_csv('https://covid.ourworldindata.org/data/ecdc/total_deaths.csv').fillna(0) #NÚMERO DE MUERTES TOTALES
cn = pd.read_csv('https://covid.ourworldindata.org/data/ecdc/new_cases.csv').fillna(0) #NÚMERO DE CASOS NUEVOS
mn = pd.read_csv('https://covid.ourworldindata.org/data/ecdc/new_deaths.csv').fillna(0) #NÚMERO DE MUERTES TOTALES

cn.iloc[spike] = cn.iloc[spike-1]
mn.tail()
# Out:
#            date  World  Afghanistan  ...  Yemen  Zambia  Zimbabwe
# 300  2020-10-26   4441          3.0  ...    0.0     0.0       1.0
# 301  2020-10-27   5462          8.0  ...    0.0     0.0       5.0
# 302  2020-10-28   7300          7.0  ...    0.0     0.0       0.0
# 303  2020-10-29   7176          0.0  ...    0.0    44.0       0.0
# 304  2020-10-30   6834          3.0  ...    0.0     0.0       0.0
#
# [5 rows x 215 columns]

# %%
#NÚMERO  DESCRIPTIVO ESTADÍSTICAMENTE DE CASOS NUEVOS POR DÍAS DESDE 22/03 HASTA 29/30 POR PAÍS
cn.describe()
# Out:
#                World  Afghanistan  ...      Zambia   Zimbabwe
# count     305.000000   305.000000  ...  305.000000  305.00000
# mean   147893.498361   135.304918  ...   53.524590   27.37377
# std    128069.816740   213.314574  ...   99.417052   55.86130
# min         0.000000     0.000000  ...    0.000000    0.00000
# 25%     12479.000000     0.000000  ...    0.000000    0.00000
# 50%    108785.000000    38.000000  ...    3.000000    3.00000
# 75%    258065.000000   164.000000  ...   65.000000   27.00000
# max    511285.000000  1063.000000  ...  527.000000  490.00000
#
# [8 rows x 214 columns]

# %%
#NÚMERO DESCRIPTIVO ESTADÍSTICAMENTE DE CASOS TOTALES POR DÍAS DESDE 22/03 HASTA 29/30 POR PAÍS
ct.describe()
# Out:
#               World   Afghanistan  ...        Zambia     Zimbabwe
# count  3.050000e+02    305.000000  ...    305.000000   305.000000
# mean   1.182324e+07  18279.045902  ...   4286.062295  2244.560656
# std    1.323947e+07  17484.626444  ...   5838.516559  3151.371638
# min    2.700000e+01      0.000000  ...      0.000000     0.000000
# 25%    1.734920e+05     16.000000  ...      0.000000     0.000000
# 50%    6.040543e+06  14525.000000  ...   1057.000000   174.000000
# 75%    2.126224e+07  37431.000000  ...   9021.000000  5072.000000
# max    4.512060e+07  41268.000000  ...  16325.000000  8349.000000
#
# [8 rows x 214 columns]

# %%
#NÚMERO DESCRIPTIVO ESTADÍSTICAMENTE DE MUERTES TOTALES POR DÍAS DESDE 22/03 HASTA 29/30 POR PAÍS
mt.describe()
# Out:
#               World  Afghanistan  ...      Zambia    Zimbabwe
# count  3.050000e+02   305.000000  ...  305.000000  305.000000
# mean   4.248391e+05   598.429508  ...   99.609836   60.977049
# std    3.861818e+05   627.793543  ...  136.339898   91.145792
# min    0.000000e+00     0.000000  ...    0.000000    0.000000
# 25%    6.540000e+03     0.000000  ...    0.000000    0.000000
# 50%    3.680420e+05   249.000000  ...    7.000000    4.000000
# 75%    7.602970e+05  1363.000000  ...  256.000000  128.000000
# max    1.182408e+06  1532.000000  ...  392.000000  242.000000
#
# [8 rows x 214 columns]

# %%
#NÚMERO DESCRIPTIVO ESTADÍSTICAMENTE DE MUERTES NUEVAS POR DÍAS DESDE 22/03 HASTA 29/30 POR PAÍS
mn.describe()
# Out:
#               World  Afghanistan  ...      Zambia    Zimbabwe
# count    305.000000   305.000000  ...  305.000000  305.000000
# mean    3876.747541     5.022951  ...    1.285246    0.793443
# std     2587.302640     8.877240  ...    4.698188    2.349403
# min        0.000000     0.000000  ...    0.000000    0.000000
# 25%      606.000000     0.000000  ...    0.000000    0.000000
# 50%     4642.000000     1.000000  ...    0.000000    0.000000
# 75%     5758.000000     5.000000  ...    0.000000    0.000000
# max    10491.000000    56.000000  ...   44.000000   18.000000
#
# [8 rows x 214 columns]
